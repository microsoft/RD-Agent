# %%
# !pip install "/kaggle/input/autocorrect/autocorrect-2.6.1.tar"
# !pip install "/kaggle/input/pyspellchecker/pyspellchecker-0.7.2-py3-none-any.whl"

# %%
import numpy as np
import pandas as pd 
import lightgbm as lgb
import pickle

# %% [markdown]
# ## Utils

# %%
import optuna
from sklearn.metrics import mean_squared_error

def MCRMSE(y_trues, y_preds):
    scores = []
    idxes = y_trues.shape[1]
    for i in range(idxes):
        y_true = y_trues[:,i]
        y_pred = y_preds[:,i]
        score = mean_squared_error(y_true, y_pred, squared=False) # RMSE
        scores.append(score)
    mcrmse_score = np.mean(scores)
    return mcrmse_score, scores

def MCRMSE_SINGLE(y_trues, y_preds):
    scores = []
    mcrmse_score = mean_squared_error(y_trues, y_preds, squared=False) # RMSE
    return mcrmse_score, scores

def get_score(y_trues, y_preds, single=False):
    if single:
        mcrmse_score, scores = MCRMSE_SINGLE(y_trues, y_preds)
    else:
        mcrmse_score, scores = MCRMSE(y_trues, y_preds)
    return mcrmse_score, scores

# %%
# %%writefile filepaths.yaml
#
# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv"
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv"
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv"
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model239_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
    --model_dir_path /kaggle/input/commonlit-model239 \
    --file_paths /kaggle/working/filepaths.yaml \
    --folds "1,3"

# %%
# %%writefile filepaths.yaml
#
# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv"
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv"
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv"
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model238_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
    --model_dir_path /kaggle/input/commonlit-model238 \
    --file_paths /kaggle/working/filepaths.yaml \
    --folds "1,3"

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model238_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model238 \
#     --file_paths /kaggle/working/filepaths.yaml \
#     --folds "1,3"

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model235_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model235 \
#     --file_paths /kaggle/working/filepaths.yaml \
#     --folds "1"

# %% [markdown]
# ### Model5 - [deberta-v3-base]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model201_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model201 \
#     --file_paths /kaggle/working/filepaths.yaml \
#     --folds "0,1,2,3"

# %% [markdown]
# ### model6 [deberta-v3-base]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model34_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model34 \
#     --file_paths /kaggle/working/filepaths.yaml

# %% [markdown]
# ### Model7 [deberta-v3-base]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model35_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model35 \
#     --file_paths /kaggle/working/filepaths.yaml

# %% [markdown]
# ### Model9 [deberta-v3-base]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model111_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model111 \
#     --file_paths /kaggle/working/filepaths.yaml

# %% [markdown]
# ### Model102 [deberta-v3-large]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model113_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model113 \
#     --file_paths /kaggle/working/filepaths.yaml

# %% [markdown]
# ### Model103 [deberta-v3-large]

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model117_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model117 \
#     --file_paths /kaggle/working/filepaths.yaml

# %% [markdown]
# ### model 102

# %%
# %%writefile filepaths.yaml

# SUB_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv" 
# TEST_SUMMARIES_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv" 
# TEST_PROMPTS_CSV: "/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv" 
# CONFIG_PATH: "/kaggle/input/commonlit-code/config/model102_training_config.yaml"

# %%
# !python /kaggle/input/commonlit-code/src/inference.py \
#     --model_dir_path /kaggle/input/commonlit-model102 \
#     --file_paths /kaggle/working/filepaths.yaml

# %%
import numpy as np

def apply_smoothing(predictions, alpha=0.5):
    """
    Apply post-processing smoothing to a set of predictions.

    Parameters:
    - predictions: NumPy array containing the model's raw predictions.
    - alpha: Smoothing parameter (0 <= alpha <= 1). Higher values increase smoothing.

    Returns:
    - smoothed_predictions: NumPy array with smoothed predictions.
    """
    num_samples, num_columns = predictions.shape
    
    # Initialize an array to store smoothed predictions
    smoothed_predictions = np.zeros_like(predictions)
    
    # Apply smoothing to each column (prediction)
    for col in range(num_columns):
        column_predictions = predictions[:, col]
        smoothed_predictions[:, col] = column_predictions * (1 - alpha) + alpha * column_predictions.mean()
    
    return smoothed_predictions

# %%
def prepare_weighted_ensemble(weights):
    target_columns = ['content', 'wording']
    preds_final = None

    for idx, (model_name, model_wt) in enumerate(weights.items()):
        df = pd.read_csv(f'./commonlit-{model_name}_submission.csv').sort_values('student_id').reset_index(drop=True)
#         df[['content', 'wording']] = apply_smoothing(df[['content', 'wording']].values, alpha=0.025)

        print(model_name, model_wt)
        if idx == 0:
            preds_final = df[['content', 'wording']].values * model_wt
        else:
            preds_final += df[['content', 'wording']].values * model_wt

    preds_final = preds_final/np.sum(list(weights.values()))
    print(np.sum(list(weights.values())))

    model_ensemble = pd.read_csv(f"/kaggle/working/commonlit-{list(weights.keys())[0]}_submission.csv").sort_values('student_id').reset_index(drop=True)
    model_ensemble[['content', 'wording']] = preds_final
    model_ensemble = model_ensemble[['student_id'] + target_columns]
    return model_ensemble

# %% [markdown]
# ### LGBM

# %%
def get_lgbm_model_dict(weights):
    csvs = [
        "/kaggle/input/commonlit-code/data/oofs/model201.csv", # 0.5542978760272054
#         "/kaggle/input/commonlit-code/data/oofs/model34.csv", # 0.5653015550715024  
    ]
    
    train_csv = "/kaggle/input/commonlit-evaluate-student-summaries/summaries_train.csv"
    train_df = pd.read_csv(train_csv)

    oofs = []
    for csv in csvs:
        df = pd.read_csv(csv)
        df = df.loc[df.student_id.isin(train_df.student_id.values)].reset_index(drop=True)    
        merged_df = df.merge(
            train_df,
            left_on='student_id',
            right_on='student_id',
            how='outer',
            suffixes=('_pred','_gt')
        ) 
        merged_df.dropna()
        oofs.append(merged_df)
    
    
#     ### get weighted ensemble trained file
#     oof_final = None
#     for idx, (model_key, model_wt) in enumerate(weights.items()):
#         print(model_key, model_wt)
#         if idx == 0:
#             oof_final = oofs[idx][['content_pred', 'wording_pred']].values * model_wt
#         else:
#             oof_final += oofs[idx][['content_pred', 'wording_pred']].values * model_wt
#     oof_final = oof_final/np.sum(list(weights.values()))
#     print(np.sum(list(weights.values())))

#     oof_ensemble = oofs[0].copy()
#     oof_ensemble[['content_pred', 'wording_pred']] = oof_final



    train = pd.read_csv("/kaggle/input/commonlit-code/data/raw/train_folds_processed.csv").sort_values('student_id').reset_index(drop=True)

    dfs = []
    for csv in csvs:
        model_name = csv.split("/")[-1].split(".")[0]
        df = pd.read_csv(csv)
        df = df.loc[df.student_id.isin(train_df.student_id.values)].sort_values('student_id').reset_index(drop=True)
        df = df[['student_id', 'content', 'wording']]
        train[[f'content_{model_name}', f'wording_{model_name}']] = df[['content', 'wording']]


#     ## add weighted ensemble
#     oof_ensemble = oof_ensemble.loc[df.student_id.isin(train_df.student_id.values)].sort_values('student_id').reset_index(drop=True)
#     oof_ensemble = oof_ensemble[['student_id', 'content_pred', 'wording_pred']]
#     train[[f'content_ensemble', f'wording_ensemble']] = oof_ensemble[['content_pred', 'wording_pred']]
    

    ### started training lgbm on train set
    targets = ["content", "wording"]
    drop_columns = ["fold", "student_id", "prompt_id", "text", 
                    "prompt_question", "prompt_title", 
                    "prompt_text"
                   ] + targets
    
    
    model_dict = {}
    for target in targets:
        models = []

        for fold in range(4):
            X_train_cv = train[train["fold"] != fold].drop(columns=drop_columns)
            y_train_cv = train[train["fold"] != fold][target]

            X_eval_cv = train[train["fold"] == fold].drop(columns=drop_columns)
            y_eval_cv = train[train["fold"] == fold][target]

            dtrain = lgb.Dataset(X_train_cv, label=y_train_cv)
            dval = lgb.Dataset(X_eval_cv, label=y_eval_cv)

            params = {
                'boosting_type': 'gbdt',
                'random_state': 42,
                'objective': 'regression',
                'metric': 'rmse',
                'learning_rate': 0.049,
                'max_depth': 3,
                'lambda_l1': 0.1,
                'lambda_l2': 0.01
            }

            evaluation_results = {}
            model = lgb.train(
              params,
              num_boost_round=10000,
              valid_names=['train', 'valid'],
              train_set=dtrain,
              valid_sets=[dval],
              callbacks=[
                  lgb.early_stopping(stopping_rounds=30, verbose=True),
                  lgb.log_evaluation(10),
                  lgb.callback.record_evaluation(evaluation_results)
                ],
            )
            models.append(model)

        model_dict[target] = models
        
        
        
    # Calculate CV on train set
    rmses = []
    for target in targets:
        models = model_dict[target]
        preds = []
        trues = []
        for fold, model in enumerate(models):
            X_eval_cv = train[train["fold"] == fold].drop(columns=drop_columns)
            y_eval_cv = train[train["fold"] == fold][target]
            pred = model.predict(X_eval_cv)
            trues.extend(y_eval_cv)
            preds.extend(pred)

        rmse = np.sqrt(mean_squared_error(trues, preds))
        print(f"{target}_rmse : {rmse}")
        rmses = rmses + [rmse]

    print(f"mcrmse : {sum(rmses) / len(rmses)}")
        
    return model_dict

# %%
def get_lgbm_preds(model_dict, weights):
    targets = ['content', 'wording']
    drop_columns = [
        "student_id", "prompt_id", "text", "prompt_question", "prompt_title", "prompt_text"
    ]

    test_df = pd.read_csv("/kaggle/working/test_processed.csv").sort_values('student_id').reset_index(drop=True)

    for idx, (model_name, model_wt) in enumerate(weights.items()):
        df = pd.read_csv(f'./commonlit-{model_name}_submission.csv').sort_values('student_id').reset_index(drop=True)
        test_df[[f'content_{model_name}', f'wording_{model_name}']] = df[['content', 'wording']]

        
#     model_ensemble = prepare_weighted_ensemble(weights)
#     test_df[[f'content_ensemble', f'wording_ensemble']] = model_ensemble[['content', 'wording']]

    
    pred_dict = {}
    for target in targets:
        models = model_dict[target]
        preds = []
        for fold, model in enumerate(models):
            X_eval_cv = test_df.drop(columns=drop_columns)
            pred = model.predict(X_eval_cv)
            preds.append(pred)

        pred_dict[target] = np.mean(preds, axis=0)
        
    ## create submission file
    test_df['content'] = pred_dict['content']
    test_df['wording'] = pred_dict['wording']
    return test_df[["student_id", "content", "wording"]]

# %%
USE_LGBM = False

weights = {
#     'model201': 1.0,
    'model238': 1.0,
    'model239': 1.0,
#     'model238': 1.0,
#      'model35': 0.376970559396996,
#      'model111': 0.13570404395349056,
#      'model113': 0.7333062601703223,
#      'model117': 0.24309630925920117,
#      'model102': 0.9076993360931804
}


if USE_LGBM:
    model_dict = get_lgbm_model_dict(weights)
    lgbm_ensemble = get_lgbm_preds(model_dict, weights)
    lgbm_ensemble.to_csv('submission.csv', index=False) 
    print(lgbm_ensemble.head(4))
else:
    weighted_ensemble = prepare_weighted_ensemble(weights)
    weighted_ensemble.to_csv('submission.csv', index=False)
    print(weighted_ensemble.head(4))
